# %% [markdown]
# # test version, try to clean column: student_name

# %%
import os
import pandas as pd

student_data_to_load = os.path.join('Resources', 'students_complete.csv')
student_data_df = pd.read_csv(student_data_to_load)

student_data_df.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score
# 0             66          79
# 1             94          61
# 2             90          60
# 3             67          58
# 4             97          84

# %% [markdown]
# ### use tolist()

# %%
# use _df[].tolist() seperate a column into a list
student_names = student_data_df["student_name"].tolist()
student_names[:10]
# Out:
# ['Paul Bradley',
#  'Victor Smith',
#  'Kevin Rodriguez',
#  'Dr. Richard Scott',
#  'Bonnie Ray',
#  'Bryan Miranda',
#  'Sheena Carter',
#  'Nicole Baker',
#  'Michael Roth',
#  'Matthew Greene']

# %%
# init three lists to append the wrong student names
students_to_fix=list()
prefixes=list()
suffixes=list()
for name in student_names:
    word=name.split()
    if len(word) >= 3:
        students_to_fix.append(name)
print(len(students_to_fix))
students_to_fix
# Out:
# 1531
# ['Dr. Richard Scott',
#  'Dr. Jordan Carson',
#  'Madeline Snyder MD',
#  'Mr. Dylan Taylor MD',
#  'Dr. Scott Gill',
#  'Miss Madison Everett',
#  'Virginia Ramirez MD',
#  'Joseph Morales III',
#  'Angela Perkins DVM',
#  'Heather Allen MD',
#  'Luke Lowery MD',
#  'Dr. Larry Hines',
#  'Emily Cardenas MD',
#  'Mrs. Elizabeth Espinoza DDS',
#  'Mrs. Lisa Becker',
#  'Mr. Travis Young',
#  'Paula Fernandez DVM',
#  'Dr. Xavier Bell II',
#  'Andrew Hanson MD',
#  'Mr. Roberto Wright MD',
#  'Mr. Dale Miller',
#  'Mary Gonzalez DDS',
#  'Mrs. Cindy Brown',
#  'James White MD',
#  'Donald Gill DDS',
#  'Mrs. Catherine Williams MD',
#  'Ashley Caldwell MD',
#  'Mr. Jared Campbell',
#  'Michael Moreno PhD',
#  'Tara Parker MD',
#  'Shawn Williams DVM',
#  'Dr. Alicia Martinez',
#  'Mr. Timothy Anderson',
#  'Mrs. Paula Lee',
#  'Mr. Elijah Hall',
#  'Mr. Raymond Stone',
#  'John Dickerson MD',
#  'Mr. Alex Franklin',
#  'Mrs. Jessica Dunn',
#  'Mr. Michael Stevenson',
# ...

# %%
for name in students_to_fix:
            
    if len(name.split()[0]) <=4:
         prefixes.append(name.split()[0])
    if len(name.split()[-1]) <=3:  
         suffixes.append(name.split()[-1])
set(prefixes)

set(suffixes)
# Out:
# {'Cox',
#  'DDS',
#  'DVM',
#  'Day',
#  'II',
#  'III',
#  'IV',
#  'Jr.',
#  'Kim',
#  'Lee',
#  'Li',
#  'MD',
#  'PhD',
#  'Roy',
#  'V'}

# %%
#after set(), (like a only-value dictionary) use string method to replace() or strip()[not work well, removes letters]
#make a new list for ready to remove name
#return to DataFrame go through student_name column, replace(word, '')

prefixes_suffixes = ["Dr. ", "Mr. ","Ms. ", "Mrs. ", "Miss ", " MD", " DDS", " DVM", " PhD"]

for word in prefixes_suffixes:
    student_data_df['student_name'] = student_data_df['student_name'].str.replace(word,'')
    
student_data_df.head(10)
# Out:
#    Student ID     student_name gender grade        school_name  reading_score  \
# 0           0     Paul Bradley      M   9th  Huang High School             66
# 1           1     Victor Smith      M  12th  Huang High School             94
# 2           2  Kevin Rodriguez      M  12th  Huang High School             90
# 3           3    Richard Scott      M  12th  Huang High School             67
# 4           4       Bonnie Ray      F   9th  Huang High School             97
# 5           5    Bryan Miranda      M   9th  Huang High School             94
# 6           6    Sheena Carter      F  11th  Huang High School             82
# 7           7     Nicole Baker      F  12th  Huang High School             96
# 8           8     Michael Roth      M  10th  Huang High School             95
# 9           9   Matthew Greene      M  10th  Huang High School             96
#
#    math_score
# 0          79
# 1          61
# 2          60
# 3          58
# 4          84
# 5          94
# ...

# %% [markdown]
# ### put cleaned student name in a new list, to double check

# %%
#check len() of each name again
#now, if len greater than 3, means has family names, not prefix
students_fixed=list()
for name in student_names:
    word=name.split()
    if len(word) >= 3:
        students_fixed.append(name)
len(students_fixed)
#print(students_fixed)
# Out:
# 1531

# %% [markdown]
# ### try, test format and map the whole column value

# %%
student_data_df["reading_score"]=student_data_df["reading_score"].map('{:.2f}'.format)
student_data_df.head(10)
# Out:
#    Student ID     student_name gender grade        school_name reading_score  \
# 0           0     Paul Bradley      M   9th  Huang High School         66.00
# 1           1     Victor Smith      M  12th  Huang High School         94.00
# 2           2  Kevin Rodriguez      M  12th  Huang High School         90.00
# 3           3    Richard Scott      M  12th  Huang High School         67.00
# 4           4       Bonnie Ray      F   9th  Huang High School         97.00
# 5           5    Bryan Miranda      M   9th  Huang High School         94.00
# 6           6    Sheena Carter      F  11th  Huang High School         82.00
# 7           7     Nicole Baker      F  12th  Huang High School         96.00
# 8           8     Michael Roth      M  10th  Huang High School         95.00
# 9           9   Matthew Greene      M  10th  Huang High School         96.00
#
#    math_score
# 0          79
# 1          61
# 2          60
# 3          58
# 4          84
# 5          94
# ...
